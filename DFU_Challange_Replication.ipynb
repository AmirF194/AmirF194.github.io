# %% [markdown]
# <a href="https://colab.research.google.com/github/AmirF194/AmirF194.github.io/blob/main/DFU_Challange_Replication.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World!")
# Out:
# Hello, World!
